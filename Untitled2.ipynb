# %%
# !pwd
# Out:
# /content

# %%
# !chdir 'drive'
# Out:
# /bin/bash: chdir: command not found

# %%
# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Feb 29 13:22 .
# drwxr-xr-x 1 root root 4096 Feb 29 13:19 ..
# drwxr-xr-x 1 root root 4096 Feb 19 17:12 .config
# drwx------ 3 root root 4096 Feb 29 13:22 drive
# drwxr-xr-x 1 root root 4096 Feb  5 18:37 sample_data
