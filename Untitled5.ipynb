# %%
import os
os.chdir('/content/drive/My Drive/test')

# %%
# !ls -al
# Out:
# total 21
# drwx------ 8 root root  4096 Feb 29 16:53 .git
# -rw------- 1 root root     8 Feb 29 16:44 test222
# -rw------- 1 root root   953 Feb 29 16:44 Untitled0.ipynb
# -rw------- 1 root root 15598 Feb 29 16:47 Untitled454222.ipynb

# %%
# !rm -rf .git

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/test/.git/

# %%
# !git add .

# %%
# !git config --global user.email "psangkuk@gmail.com"
# !git config --global user.name "psangkuk"

# %%
# !git commit -m "initial commit"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git remote add origin https://github.com/psangkuk/test3.git

# %%
# !git push -u --force origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 4.53 KiB | 1.13 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/psangkuk/test.git
#  + 63263ff...40b985e master -> master (forced update)
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git remote rm origin
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin master -f
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git clone https://github.com/psangkuk/test.git
# Out:
# Cloning into 'test'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.
