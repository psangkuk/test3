# %%
import os
os.chdir('drive/My Drive/test3')

# %%
# !ls -al
# Out:
# total 227
# -rw------- 1 root root   3632 Feb 29 15:11 deeplearning.ipynb
# -rw------- 1 root root  15643 Feb 29 12:38 temp.ipynb
# -rw------- 1 root root 178982 Feb 29 14:44 tensorflow.ipynb
# -rw------- 1 root root    374 Feb 29 11:54 test333.ipynb
# -rw------- 1 root root    317 Feb 29 16:24 Untitled
# -rw------- 1 root root    367 Feb 29 12:11 Untitled0.ipynb
# -rw------- 1 root root    821 Feb 29 12:15 Untitled1.ipynb
# -rw------- 1 root root   1987 Feb 29 13:27 Untitled2.ipynb
# -rw------- 1 root root    397 Feb 29 15:14 Untitled3.ipynb
# -rw------- 1 root root  15598 Feb 29 16:17 Untitled454222.ipynb
# -rw------- 1 root root   4022 Feb 29 15:24 Untitled4.ipynb
# -rw------- 1 root root   7274 Feb 29 16:28 Untitled5.ipynb

# %%
# !rm -rf .git

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/test3/.git/

# %%
# !git add .

# %%
# !git commit -m "initial commit"
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push -u --force origin master
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git config --global user.email "psangkuk@gmail.com"
# !git config --global user.name "psangkuk"

# %%
# !git remote rm origin
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote add origin https://psangkuk:parkskgithub12@github.com/psangkuk/test3.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin master -f
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git clone https://github.com/psangkuk/test3.git
# Out:
# Cloning into 'test3'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 25 (delta 14), reused 25 (delta 14), pack-reused 0
# Unpacking objects: 100% (25/25), done.
